# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time

os.makedirs('logs', exist_ok=True)

logging.basicConfig(
    filename="logs/ingestion_db.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
console_handler.setFormatter(formatter)
logging.getLogger().addHandler(console_handler)

engine = create_engine('sqlite:///inventory.db')

def load_raw_data():
    '''This function will load the CSVs as dataframe and ingest into db'''
    start = time.time()
    logging.info('Starting data ingestion process...')
    
    if not os.path.exists('dataset'):
        logging.error('Dataset directory does not exist')
        return
    
    csv_files = [f for f in os.listdir('dataset') if f.endswith('.csv')]
    if not csv_files:
        logging.warning('No CSV files found in dataset directory')
        return
    
    logging.info(f'Found {len(csv_files)} CSV files to process')
    
    for file in csv_files:
        logging.info(f'Starting to process file: {file}')
        try:
            chunk_size = 20000 
            table_name = file[:-4]
            
            total_rows = 0
            for chunk_number, chunk in enumerate(pd.read_csv(f'dataset/{file}', chunksize=chunk_size)):
                print(f"Processing {file}, chunk {chunk_number}, shape: {chunk.shape}")
                
                if_exists = 'replace' if chunk_number == 0 else 'append'
                chunk.to_sql(table_name, engine, if_exists=if_exists, index=False)
                total_rows += len(chunk)
            
            logging.info(f"Completed processing {file} - Total rows: {total_rows}")
            print(f"Completed processing {file} - Total rows: {total_rows}")
            
        except Exception as e:
            logging.error(f"Error processing file {file}: {str(e)}")
            print(f"Error processing file {file}: {str(e)}")
    
    end = time.time()
    total_time = (end - start) / 60
    logging.info('-------------Ingestion Complete------------')
    logging.info(f'Total Time Taken: {total_time:.2f} minutes')
    print(f'Total Time Taken: {total_time:.2f} minutes')

if __name__ == '__main__': 
    load_raw_data()
# Out:
# 2025-06-27 10:46:27,942 - INFO - Starting data ingestion process...
# 2025-06-27 10:46:27,945 - INFO - Found 6 CSV files to process
# 2025-06-27 10:46:27,946 - INFO - Starting to process file: begin_inventory.csv
# Processing begin_inventory.csv, chunk 0, shape: (20000, 9)
# Processing begin_inventory.csv, chunk 1, shape: (20000, 9)
# Processing begin_inventory.csv, chunk 2, shape: (20000, 9)
# Processing begin_inventory.csv, chunk 3, shape: (20000, 9)
# Processing begin_inventory.csv, chunk 4, shape: (20000, 9)
# Processing begin_inventory.csv, chunk 5, shape: (20000, 9)
# Processing begin_inventory.csv, chunk 6, shape: (20000, 9)
# Processing begin_inventory.csv, chunk 7, shape: (20000, 9)
# Processing begin_inventory.csv, chunk 8, shape: (20000, 9)
# Processing begin_inventory.csv, chunk 9, shape: (20000, 9)
# 2025-06-27 10:46:34,020 - INFO - Completed processing begin_inventory.csv - Total rows: 206529
# 2025-06-27 10:46:34,021 - INFO - Starting to process file: end_inventory.csv
# Processing begin_inventory.csv, chunk 10, shape: (6529, 9)
# Completed processing begin_inventory.csv - Total rows: 206529
# Processing end_inventory.csv, chunk 0, shape: (20000, 9)
# Processing end_inventory.csv, chunk 1, shape: (20000, 9)
# Processing end_inventory.csv, chunk 2, shape: (20000, 9)
# Processing end_inventory.csv, chunk 3, shape: (20000, 9)
# Processing end_inventory.csv, chunk 4, shape: (20000, 9)
# Processing end_inventory.csv, chunk 5, shape: (20000, 9)
# Processing end_inventory.csv, chunk 6, shape: (20000, 9)
# Processing end_inventory.csv, chunk 7, shape: (20000, 9)
# Processing end_inventory.csv, chunk 8, shape: (20000, 9)
# Processing end_inventory.csv, chunk 9, shape: (20000, 9)
# Processing end_inventory.csv, chunk 10, shape: (20000, 9)
# 2025-06-27 10:46:40,488 - INFO - Completed processing end_inventory.csv - Total rows: 224489
# 2025-06-27 10:46:40,491 - INFO - Starting to process file: purchases.csv
# Processing end_inventory.csv, chunk 11, shape: (4489, 9)
# Completed processing end_inventory.csv - Total rows: 224489
# Processing purchases.csv, chunk 0, shape: (20000, 16)
# Processing purchases.csv, chunk 1, shape: (20000, 16)
# Processing purchases.csv, chunk 2, shape: (20000, 16)
# Processing purchases.csv, chunk 3, shape: (20000, 16)
# Processing purchases.csv, chunk 4, shape: (20000, 16)
# Processing purchases.csv, chunk 5, shape: (20000, 16)
# Processing purchases.csv, chunk 6, shape: (20000, 16)
# Processing purchases.csv, chunk 7, shape: (20000, 16)
# Processing purchases.csv, chunk 8, shape: (20000, 16)
# Processing purchases.csv, chunk 9, shape: (20000, 16)
# Processing purchases.csv, chunk 10, shape: (20000, 16)
# Processing purchases.csv, chunk 11, shape: (20000, 16)
# Processing purchases.csv, chunk 12, shape: (20000, 16)
# Processing purchases.csv, chunk 13, shape: (20000, 16)
# Processing purchases.csv, chunk 14, shape: (20000, 16)
# Processing purchases.csv, chunk 15, shape: (20000, 16)
# Processing purchases.csv, chunk 16, shape: (20000, 16)
# Processing purchases.csv, chunk 17, shape: (20000, 16)
# Processing purchases.csv, chunk 18, shape: (20000, 16)
# Processing purchases.csv, chunk 19, shape: (20000, 16)
# Processing purchases.csv, chunk 20, shape: (20000, 16)
# Processing purchases.csv, chunk 21, shape: (20000, 16)
# Processing purchases.csv, chunk 22, shape: (20000, 16)
# Processing purchases.csv, chunk 23, shape: (20000, 16)
# Processing purchases.csv, chunk 24, shape: (20000, 16)
# Processing purchases.csv, chunk 25, shape: (20000, 16)
# Processing purchases.csv, chunk 26, shape: (20000, 16)
# Processing purchases.csv, chunk 27, shape: (20000, 16)
# Processing purchases.csv, chunk 28, shape: (20000, 16)
# Processing purchases.csv, chunk 29, shape: (20000, 16)
# Processing purchases.csv, chunk 30, shape: (20000, 16)
# Processing purchases.csv, chunk 31, shape: (20000, 16)
# Processing purchases.csv, chunk 32, shape: (20000, 16)
# Processing purchases.csv, chunk 33, shape: (20000, 16)
# Processing purchases.csv, chunk 34, shape: (20000, 16)
# Processing purchases.csv, chunk 35, shape: (20000, 16)
# Processing purchases.csv, chunk 36, shape: (20000, 16)
# Processing purchases.csv, chunk 37, shape: (20000, 16)
# Processing purchases.csv, chunk 38, shape: (20000, 16)
# Processing purchases.csv, chunk 39, shape: (20000, 16)
# Processing purchases.csv, chunk 40, shape: (20000, 16)
# Processing purchases.csv, chunk 41, shape: (20000, 16)
# Processing purchases.csv, chunk 42, shape: (20000, 16)
# Processing purchases.csv, chunk 43, shape: (20000, 16)
# Processing purchases.csv, chunk 44, shape: (20000, 16)
# Processing purchases.csv, chunk 45, shape: (20000, 16)
# Processing purchases.csv, chunk 46, shape: (20000, 16)
# Processing purchases.csv, chunk 47, shape: (20000, 16)
# Processing purchases.csv, chunk 48, shape: (20000, 16)
# Processing purchases.csv, chunk 49, shape: (20000, 16)
# Processing purchases.csv, chunk 50, shape: (20000, 16)
# Processing purchases.csv, chunk 51, shape: (20000, 16)
# Processing purchases.csv, chunk 52, shape: (20000, 16)
# Processing purchases.csv, chunk 53, shape: (20000, 16)
# Processing purchases.csv, chunk 54, shape: (20000, 16)
# Processing purchases.csv, chunk 55, shape: (20000, 16)
# Processing purchases.csv, chunk 56, shape: (20000, 16)
# Processing purchases.csv, chunk 57, shape: (20000, 16)
# Processing purchases.csv, chunk 58, shape: (20000, 16)
# Processing purchases.csv, chunk 59, shape: (20000, 16)
# Processing purchases.csv, chunk 60, shape: (20000, 16)
# Processing purchases.csv, chunk 61, shape: (20000, 16)
# Processing purchases.csv, chunk 62, shape: (20000, 16)
# Processing purchases.csv, chunk 63, shape: (20000, 16)
# Processing purchases.csv, chunk 64, shape: (20000, 16)
# Processing purchases.csv, chunk 65, shape: (20000, 16)
# Processing purchases.csv, chunk 66, shape: (20000, 16)
# Processing purchases.csv, chunk 67, shape: (20000, 16)
# Processing purchases.csv, chunk 68, shape: (20000, 16)
# Processing purchases.csv, chunk 69, shape: (20000, 16)
# Processing purchases.csv, chunk 70, shape: (20000, 16)
# Processing purchases.csv, chunk 71, shape: (20000, 16)
# Processing purchases.csv, chunk 72, shape: (20000, 16)
# Processing purchases.csv, chunk 73, shape: (20000, 16)
# Processing purchases.csv, chunk 74, shape: (20000, 16)
# Processing purchases.csv, chunk 75, shape: (20000, 16)
# Processing purchases.csv, chunk 76, shape: (20000, 16)
# Processing purchases.csv, chunk 77, shape: (20000, 16)
# Processing purchases.csv, chunk 78, shape: (20000, 16)
# Processing purchases.csv, chunk 79, shape: (20000, 16)
# Processing purchases.csv, chunk 80, shape: (20000, 16)
# Processing purchases.csv, chunk 81, shape: (20000, 16)
# Processing purchases.csv, chunk 82, shape: (20000, 16)
# Processing purchases.csv, chunk 83, shape: (20000, 16)
# Processing purchases.csv, chunk 84, shape: (20000, 16)
# Processing purchases.csv, chunk 85, shape: (20000, 16)
# Processing purchases.csv, chunk 86, shape: (20000, 16)
# Processing purchases.csv, chunk 87, shape: (20000, 16)
# Processing purchases.csv, chunk 88, shape: (20000, 16)
# Processing purchases.csv, chunk 89, shape: (20000, 16)
# Processing purchases.csv, chunk 90, shape: (20000, 16)
# Processing purchases.csv, chunk 91, shape: (20000, 16)
# Processing purchases.csv, chunk 92, shape: (20000, 16)
# Processing purchases.csv, chunk 93, shape: (20000, 16)
# Processing purchases.csv, chunk 94, shape: (20000, 16)
# Processing purchases.csv, chunk 95, shape: (20000, 16)
# Processing purchases.csv, chunk 96, shape: (20000, 16)
# Processing purchases.csv, chunk 97, shape: (20000, 16)
# Processing purchases.csv, chunk 98, shape: (20000, 16)
# Processing purchases.csv, chunk 99, shape: (20000, 16)
# Processing purchases.csv, chunk 100, shape: (20000, 16)
# Processing purchases.csv, chunk 101, shape: (20000, 16)
# Processing purchases.csv, chunk 102, shape: (20000, 16)
# Processing purchases.csv, chunk 103, shape: (20000, 16)
# Processing purchases.csv, chunk 104, shape: (20000, 16)
# Processing purchases.csv, chunk 105, shape: (20000, 16)
# Processing purchases.csv, chunk 106, shape: (20000, 16)
# Processing purchases.csv, chunk 107, shape: (20000, 16)
# Processing purchases.csv, chunk 108, shape: (20000, 16)
# Processing purchases.csv, chunk 109, shape: (20000, 16)
# Processing purchases.csv, chunk 110, shape: (20000, 16)
# Processing purchases.csv, chunk 111, shape: (20000, 16)
# Processing purchases.csv, chunk 112, shape: (20000, 16)
# Processing purchases.csv, chunk 113, shape: (20000, 16)
# Processing purchases.csv, chunk 114, shape: (20000, 16)
# Processing purchases.csv, chunk 115, shape: (20000, 16)
# Processing purchases.csv, chunk 116, shape: (20000, 16)
# Processing purchases.csv, chunk 117, shape: (20000, 16)
# Processing purchases.csv, chunk 118, shape: (12474, 16)
# 2025-06-27 10:48:27,641 - INFO - Completed processing purchases.csv - Total rows: 2372474
# 2025-06-27 10:48:27,643 - INFO - Starting to process file: purchase_prices.csv
# Completed processing purchases.csv - Total rows: 2372474
# Processing purchase_prices.csv, chunk 0, shape: (12261, 9)
# 2025-06-27 10:48:27,954 - INFO - Completed processing purchase_prices.csv - Total rows: 12261
# 2025-06-27 10:48:27,956 - INFO - Starting to process file: sales.csv
# Completed processing purchase_prices.csv - Total rows: 12261
# Processing sales.csv, chunk 0, shape: (20000, 14)
# Processing sales.csv, chunk 1, shape: (20000, 14)
# Processing sales.csv, chunk 2, shape: (20000, 14)
# Processing sales.csv, chunk 3, shape: (20000, 14)
# Processing sales.csv, chunk 4, shape: (20000, 14)
# Processing sales.csv, chunk 5, shape: (20000, 14)
# Processing sales.csv, chunk 6, shape: (20000, 14)
# Processing sales.csv, chunk 7, shape: (20000, 14)
# Processing sales.csv, chunk 8, shape: (20000, 14)
# Processing sales.csv, chunk 9, shape: (20000, 14)
# Processing sales.csv, chunk 10, shape: (20000, 14)
# Processing sales.csv, chunk 11, shape: (20000, 14)
# Processing sales.csv, chunk 12, shape: (20000, 14)
# Processing sales.csv, chunk 13, shape: (20000, 14)
# Processing sales.csv, chunk 14, shape: (20000, 14)
# Processing sales.csv, chunk 15, shape: (20000, 14)
# Processing sales.csv, chunk 16, shape: (20000, 14)
# Processing sales.csv, chunk 17, shape: (20000, 14)
# Processing sales.csv, chunk 18, shape: (20000, 14)
# Processing sales.csv, chunk 19, shape: (20000, 14)
# Processing sales.csv, chunk 20, shape: (20000, 14)
# Processing sales.csv, chunk 21, shape: (20000, 14)
# Processing sales.csv, chunk 22, shape: (20000, 14)
# Processing sales.csv, chunk 23, shape: (20000, 14)
# Processing sales.csv, chunk 24, shape: (20000, 14)
# Processing sales.csv, chunk 25, shape: (20000, 14)
# Processing sales.csv, chunk 26, shape: (20000, 14)
# Processing sales.csv, chunk 27, shape: (20000, 14)
# Processing sales.csv, chunk 28, shape: (20000, 14)
# Processing sales.csv, chunk 29, shape: (20000, 14)
# Processing sales.csv, chunk 30, shape: (20000, 14)
# Processing sales.csv, chunk 31, shape: (20000, 14)
# Processing sales.csv, chunk 32, shape: (20000, 14)
# Processing sales.csv, chunk 33, shape: (20000, 14)
# Processing sales.csv, chunk 34, shape: (20000, 14)
# Processing sales.csv, chunk 35, shape: (20000, 14)
# Processing sales.csv, chunk 36, shape: (20000, 14)
# Processing sales.csv, chunk 37, shape: (20000, 14)
# Processing sales.csv, chunk 38, shape: (20000, 14)
# Processing sales.csv, chunk 39, shape: (20000, 14)
# Processing sales.csv, chunk 40, shape: (20000, 14)
# Processing sales.csv, chunk 41, shape: (20000, 14)
# Processing sales.csv, chunk 42, shape: (20000, 14)
# Processing sales.csv, chunk 43, shape: (20000, 14)
# Processing sales.csv, chunk 44, shape: (20000, 14)
# Processing sales.csv, chunk 45, shape: (20000, 14)
# Processing sales.csv, chunk 46, shape: (20000, 14)
# Processing sales.csv, chunk 47, shape: (20000, 14)
# Processing sales.csv, chunk 48, shape: (20000, 14)
# Processing sales.csv, chunk 49, shape: (20000, 14)
# Processing sales.csv, chunk 50, shape: (20000, 14)
# Processing sales.csv, chunk 51, shape: (20000, 14)
# Processing sales.csv, chunk 52, shape: (20000, 14)
# Processing sales.csv, chunk 53, shape: (20000, 14)
# Processing sales.csv, chunk 54, shape: (20000, 14)
# Processing sales.csv, chunk 55, shape: (20000, 14)
# Processing sales.csv, chunk 56, shape: (20000, 14)
# Processing sales.csv, chunk 57, shape: (20000, 14)
# Processing sales.csv, chunk 58, shape: (20000, 14)
# Processing sales.csv, chunk 59, shape: (20000, 14)
# Processing sales.csv, chunk 60, shape: (20000, 14)
# Processing sales.csv, chunk 61, shape: (20000, 14)
# Processing sales.csv, chunk 62, shape: (20000, 14)
# Processing sales.csv, chunk 63, shape: (20000, 14)
# Processing sales.csv, chunk 64, shape: (20000, 14)
# Processing sales.csv, chunk 65, shape: (20000, 14)
# Processing sales.csv, chunk 66, shape: (20000, 14)
# Processing sales.csv, chunk 67, shape: (20000, 14)
# Processing sales.csv, chunk 68, shape: (20000, 14)
# Processing sales.csv, chunk 69, shape: (20000, 14)
# Processing sales.csv, chunk 70, shape: (20000, 14)
# Processing sales.csv, chunk 71, shape: (20000, 14)
# Processing sales.csv, chunk 72, shape: (20000, 14)
# Processing sales.csv, chunk 73, shape: (20000, 14)
# Processing sales.csv, chunk 74, shape: (20000, 14)
# Processing sales.csv, chunk 75, shape: (20000, 14)
# Processing sales.csv, chunk 76, shape: (20000, 14)
# Processing sales.csv, chunk 77, shape: (20000, 14)
# Processing sales.csv, chunk 78, shape: (20000, 14)
# Processing sales.csv, chunk 79, shape: (20000, 14)
# Processing sales.csv, chunk 80, shape: (20000, 14)
# Processing sales.csv, chunk 81, shape: (20000, 14)
# Processing sales.csv, chunk 82, shape: (20000, 14)
# Processing sales.csv, chunk 83, shape: (20000, 14)
# Processing sales.csv, chunk 84, shape: (20000, 14)
# Processing sales.csv, chunk 85, shape: (20000, 14)
# Processing sales.csv, chunk 86, shape: (20000, 14)
# Processing sales.csv, chunk 87, shape: (20000, 14)
# Processing sales.csv, chunk 88, shape: (20000, 14)
# Processing sales.csv, chunk 89, shape: (20000, 14)
# Processing sales.csv, chunk 90, shape: (20000, 14)
# Processing sales.csv, chunk 91, shape: (20000, 14)
# Processing sales.csv, chunk 92, shape: (20000, 14)
# Processing sales.csv, chunk 93, shape: (20000, 14)
# Processing sales.csv, chunk 94, shape: (20000, 14)
# Processing sales.csv, chunk 95, shape: (20000, 14)
# Processing sales.csv, chunk 96, shape: (20000, 14)
# Processing sales.csv, chunk 97, shape: (20000, 14)
# Processing sales.csv, chunk 98, shape: (20000, 14)
# Processing sales.csv, chunk 99, shape: (20000, 14)
# Processing sales.csv, chunk 100, shape: (20000, 14)
# Processing sales.csv, chunk 101, shape: (20000, 14)
# Processing sales.csv, chunk 102, shape: (20000, 14)
# Processing sales.csv, chunk 103, shape: (20000, 14)
# Processing sales.csv, chunk 104, shape: (20000, 14)
# Processing sales.csv, chunk 105, shape: (20000, 14)
# Processing sales.csv, chunk 106, shape: (20000, 14)
# Processing sales.csv, chunk 107, shape: (20000, 14)
# Processing sales.csv, chunk 108, shape: (20000, 14)
# Processing sales.csv, chunk 109, shape: (20000, 14)
# Processing sales.csv, chunk 110, shape: (20000, 14)
# Processing sales.csv, chunk 111, shape: (20000, 14)
# Processing sales.csv, chunk 112, shape: (20000, 14)
# Processing sales.csv, chunk 113, shape: (20000, 14)
# Processing sales.csv, chunk 114, shape: (20000, 14)
# Processing sales.csv, chunk 115, shape: (20000, 14)
# Processing sales.csv, chunk 116, shape: (20000, 14)
# Processing sales.csv, chunk 117, shape: (20000, 14)
# Processing sales.csv, chunk 118, shape: (20000, 14)
# Processing sales.csv, chunk 119, shape: (20000, 14)
# Processing sales.csv, chunk 120, shape: (20000, 14)
# Processing sales.csv, chunk 121, shape: (20000, 14)
# Processing sales.csv, chunk 122, shape: (20000, 14)
# Processing sales.csv, chunk 123, shape: (20000, 14)
# Processing sales.csv, chunk 124, shape: (20000, 14)
# Processing sales.csv, chunk 125, shape: (20000, 14)
# Processing sales.csv, chunk 126, shape: (20000, 14)
# Processing sales.csv, chunk 127, shape: (20000, 14)
# Processing sales.csv, chunk 128, shape: (20000, 14)
# Processing sales.csv, chunk 129, shape: (20000, 14)
# Processing sales.csv, chunk 130, shape: (20000, 14)
# Processing sales.csv, chunk 131, shape: (20000, 14)
# Processing sales.csv, chunk 132, shape: (20000, 14)
# Processing sales.csv, chunk 133, shape: (20000, 14)
# Processing sales.csv, chunk 134, shape: (20000, 14)
# Processing sales.csv, chunk 135, shape: (20000, 14)
# Processing sales.csv, chunk 136, shape: (20000, 14)
# Processing sales.csv, chunk 137, shape: (20000, 14)
# Processing sales.csv, chunk 138, shape: (20000, 14)
# Processing sales.csv, chunk 139, shape: (20000, 14)
# Processing sales.csv, chunk 140, shape: (20000, 14)
# Processing sales.csv, chunk 141, shape: (20000, 14)
# Processing sales.csv, chunk 142, shape: (20000, 14)
# Processing sales.csv, chunk 143, shape: (20000, 14)
# Processing sales.csv, chunk 144, shape: (20000, 14)
# Processing sales.csv, chunk 145, shape: (20000, 14)
# Processing sales.csv, chunk 146, shape: (20000, 14)
# Processing sales.csv, chunk 147, shape: (20000, 14)
# Processing sales.csv, chunk 148, shape: (20000, 14)
# Processing sales.csv, chunk 149, shape: (20000, 14)
# Processing sales.csv, chunk 150, shape: (20000, 14)
# Processing sales.csv, chunk 151, shape: (20000, 14)
# Processing sales.csv, chunk 152, shape: (20000, 14)
# Processing sales.csv, chunk 153, shape: (20000, 14)
# Processing sales.csv, chunk 154, shape: (20000, 14)
# Processing sales.csv, chunk 155, shape: (20000, 14)
# Processing sales.csv, chunk 156, shape: (20000, 14)
# Processing sales.csv, chunk 157, shape: (20000, 14)
# Processing sales.csv, chunk 158, shape: (20000, 14)
# Processing sales.csv, chunk 159, shape: (20000, 14)
# Processing sales.csv, chunk 160, shape: (20000, 14)
# Processing sales.csv, chunk 161, shape: (20000, 14)
# Processing sales.csv, chunk 162, shape: (20000, 14)
# Processing sales.csv, chunk 163, shape: (20000, 14)
# Processing sales.csv, chunk 164, shape: (20000, 14)
# Processing sales.csv, chunk 165, shape: (20000, 14)
# Processing sales.csv, chunk 166, shape: (20000, 14)
# Processing sales.csv, chunk 167, shape: (20000, 14)
# Processing sales.csv, chunk 168, shape: (20000, 14)
# Processing sales.csv, chunk 169, shape: (20000, 14)
# Processing sales.csv, chunk 170, shape: (20000, 14)
# Processing sales.csv, chunk 171, shape: (20000, 14)
# Processing sales.csv, chunk 172, shape: (20000, 14)
# Processing sales.csv, chunk 173, shape: (20000, 14)
# Processing sales.csv, chunk 174, shape: (20000, 14)
# Processing sales.csv, chunk 175, shape: (20000, 14)
# Processing sales.csv, chunk 176, shape: (20000, 14)
# Processing sales.csv, chunk 177, shape: (20000, 14)
# Processing sales.csv, chunk 178, shape: (20000, 14)
# Processing sales.csv, chunk 179, shape: (20000, 14)
# Processing sales.csv, chunk 180, shape: (20000, 14)
# Processing sales.csv, chunk 181, shape: (20000, 14)
# Processing sales.csv, chunk 182, shape: (20000, 14)
# Processing sales.csv, chunk 183, shape: (20000, 14)
# Processing sales.csv, chunk 184, shape: (20000, 14)
# Processing sales.csv, chunk 185, shape: (20000, 14)
# Processing sales.csv, chunk 186, shape: (20000, 14)
# Processing sales.csv, chunk 187, shape: (20000, 14)
# Processing sales.csv, chunk 188, shape: (20000, 14)
# Processing sales.csv, chunk 189, shape: (20000, 14)
# Processing sales.csv, chunk 190, shape: (20000, 14)
# Processing sales.csv, chunk 191, shape: (20000, 14)
# Processing sales.csv, chunk 192, shape: (20000, 14)
# Processing sales.csv, chunk 193, shape: (20000, 14)
# Processing sales.csv, chunk 194, shape: (20000, 14)
# Processing sales.csv, chunk 195, shape: (20000, 14)
# Processing sales.csv, chunk 196, shape: (20000, 14)
# Processing sales.csv, chunk 197, shape: (20000, 14)
# Processing sales.csv, chunk 198, shape: (20000, 14)
# Processing sales.csv, chunk 199, shape: (20000, 14)
# Processing sales.csv, chunk 200, shape: (20000, 14)
# Processing sales.csv, chunk 201, shape: (20000, 14)
# Processing sales.csv, chunk 202, shape: (20000, 14)
# Processing sales.csv, chunk 203, shape: (20000, 14)
# Processing sales.csv, chunk 204, shape: (20000, 14)
# Processing sales.csv, chunk 205, shape: (20000, 14)
# Processing sales.csv, chunk 206, shape: (20000, 14)
# Processing sales.csv, chunk 207, shape: (20000, 14)
# Processing sales.csv, chunk 208, shape: (20000, 14)
# Processing sales.csv, chunk 209, shape: (20000, 14)
# Processing sales.csv, chunk 210, shape: (20000, 14)
# Processing sales.csv, chunk 211, shape: (20000, 14)
# Processing sales.csv, chunk 212, shape: (20000, 14)
# Processing sales.csv, chunk 213, shape: (20000, 14)
# Processing sales.csv, chunk 214, shape: (20000, 14)
# Processing sales.csv, chunk 215, shape: (20000, 14)
# Processing sales.csv, chunk 216, shape: (20000, 14)
# Processing sales.csv, chunk 217, shape: (20000, 14)
# Processing sales.csv, chunk 218, shape: (20000, 14)
# Processing sales.csv, chunk 219, shape: (20000, 14)
# Processing sales.csv, chunk 220, shape: (20000, 14)
# Processing sales.csv, chunk 221, shape: (20000, 14)
# Processing sales.csv, chunk 222, shape: (20000, 14)
# Processing sales.csv, chunk 223, shape: (20000, 14)
# Processing sales.csv, chunk 224, shape: (20000, 14)
# Processing sales.csv, chunk 225, shape: (20000, 14)
# Processing sales.csv, chunk 226, shape: (20000, 14)
# Processing sales.csv, chunk 227, shape: (20000, 14)
# Processing sales.csv, chunk 228, shape: (20000, 14)
# Processing sales.csv, chunk 229, shape: (20000, 14)
# Processing sales.csv, chunk 230, shape: (20000, 14)
# Processing sales.csv, chunk 231, shape: (20000, 14)
# Processing sales.csv, chunk 232, shape: (20000, 14)
# Processing sales.csv, chunk 233, shape: (20000, 14)
# Processing sales.csv, chunk 234, shape: (20000, 14)
# Processing sales.csv, chunk 235, shape: (20000, 14)
# Processing sales.csv, chunk 236, shape: (20000, 14)
# Processing sales.csv, chunk 237, shape: (20000, 14)
# Processing sales.csv, chunk 238, shape: (20000, 14)
# Processing sales.csv, chunk 239, shape: (20000, 14)
# Processing sales.csv, chunk 240, shape: (20000, 14)
# Processing sales.csv, chunk 241, shape: (20000, 14)
# Processing sales.csv, chunk 242, shape: (20000, 14)
# Processing sales.csv, chunk 243, shape: (20000, 14)
# Processing sales.csv, chunk 244, shape: (20000, 14)
# Processing sales.csv, chunk 245, shape: (20000, 14)
# Processing sales.csv, chunk 246, shape: (20000, 14)
# Processing sales.csv, chunk 247, shape: (20000, 14)
# Processing sales.csv, chunk 248, shape: (20000, 14)
# Processing sales.csv, chunk 249, shape: (20000, 14)
# Processing sales.csv, chunk 250, shape: (20000, 14)
# Processing sales.csv, chunk 251, shape: (20000, 14)
# Processing sales.csv, chunk 252, shape: (20000, 14)
# Processing sales.csv, chunk 253, shape: (20000, 14)
# Processing sales.csv, chunk 254, shape: (20000, 14)
# Processing sales.csv, chunk 255, shape: (20000, 14)
# Processing sales.csv, chunk 256, shape: (20000, 14)
# Processing sales.csv, chunk 257, shape: (20000, 14)
# Processing sales.csv, chunk 258, shape: (20000, 14)
# Processing sales.csv, chunk 259, shape: (20000, 14)
# Processing sales.csv, chunk 260, shape: (20000, 14)
# Processing sales.csv, chunk 261, shape: (20000, 14)
# Processing sales.csv, chunk 262, shape: (20000, 14)
# Processing sales.csv, chunk 263, shape: (20000, 14)
# Processing sales.csv, chunk 264, shape: (20000, 14)
# Processing sales.csv, chunk 265, shape: (20000, 14)
# Processing sales.csv, chunk 266, shape: (20000, 14)
# Processing sales.csv, chunk 267, shape: (20000, 14)
# Processing sales.csv, chunk 268, shape: (20000, 14)
# Processing sales.csv, chunk 269, shape: (20000, 14)
# Processing sales.csv, chunk 270, shape: (20000, 14)
# Processing sales.csv, chunk 271, shape: (20000, 14)
# Processing sales.csv, chunk 272, shape: (20000, 14)
# Processing sales.csv, chunk 273, shape: (20000, 14)
# Processing sales.csv, chunk 274, shape: (20000, 14)
# Processing sales.csv, chunk 275, shape: (20000, 14)
# Processing sales.csv, chunk 276, shape: (20000, 14)
# Processing sales.csv, chunk 277, shape: (20000, 14)
# Processing sales.csv, chunk 278, shape: (20000, 14)
# Processing sales.csv, chunk 279, shape: (20000, 14)
# Processing sales.csv, chunk 280, shape: (20000, 14)
# Processing sales.csv, chunk 281, shape: (20000, 14)
# Processing sales.csv, chunk 282, shape: (20000, 14)
# Processing sales.csv, chunk 283, shape: (20000, 14)
# Processing sales.csv, chunk 284, shape: (20000, 14)
# Processing sales.csv, chunk 285, shape: (20000, 14)
# Processing sales.csv, chunk 286, shape: (20000, 14)
# Processing sales.csv, chunk 287, shape: (20000, 14)
# Processing sales.csv, chunk 288, shape: (20000, 14)
# Processing sales.csv, chunk 289, shape: (20000, 14)
# Processing sales.csv, chunk 290, shape: (20000, 14)
# Processing sales.csv, chunk 291, shape: (20000, 14)
# Processing sales.csv, chunk 292, shape: (20000, 14)
# Processing sales.csv, chunk 293, shape: (20000, 14)
# Processing sales.csv, chunk 294, shape: (20000, 14)
# Processing sales.csv, chunk 295, shape: (20000, 14)
# Processing sales.csv, chunk 296, shape: (20000, 14)
# Processing sales.csv, chunk 297, shape: (20000, 14)
# Processing sales.csv, chunk 298, shape: (20000, 14)
# Processing sales.csv, chunk 299, shape: (20000, 14)
# Processing sales.csv, chunk 300, shape: (20000, 14)
# Processing sales.csv, chunk 301, shape: (20000, 14)
# Processing sales.csv, chunk 302, shape: (20000, 14)
# Processing sales.csv, chunk 303, shape: (20000, 14)
# Processing sales.csv, chunk 304, shape: (20000, 14)
# Processing sales.csv, chunk 305, shape: (20000, 14)
# Processing sales.csv, chunk 306, shape: (20000, 14)
# Processing sales.csv, chunk 307, shape: (20000, 14)
# Processing sales.csv, chunk 308, shape: (20000, 14)
# Processing sales.csv, chunk 309, shape: (20000, 14)
# Processing sales.csv, chunk 310, shape: (20000, 14)
# Processing sales.csv, chunk 311, shape: (20000, 14)
# Processing sales.csv, chunk 312, shape: (20000, 14)
# Processing sales.csv, chunk 313, shape: (20000, 14)
# Processing sales.csv, chunk 314, shape: (20000, 14)
# Processing sales.csv, chunk 315, shape: (20000, 14)
# Processing sales.csv, chunk 316, shape: (20000, 14)
# Processing sales.csv, chunk 317, shape: (20000, 14)
# Processing sales.csv, chunk 318, shape: (20000, 14)
# Processing sales.csv, chunk 319, shape: (20000, 14)
# Processing sales.csv, chunk 320, shape: (20000, 14)
# Processing sales.csv, chunk 321, shape: (20000, 14)
# Processing sales.csv, chunk 322, shape: (20000, 14)
# Processing sales.csv, chunk 323, shape: (20000, 14)
# Processing sales.csv, chunk 324, shape: (20000, 14)
# Processing sales.csv, chunk 325, shape: (20000, 14)
# Processing sales.csv, chunk 326, shape: (20000, 14)
# Processing sales.csv, chunk 327, shape: (20000, 14)
# Processing sales.csv, chunk 328, shape: (20000, 14)
# Processing sales.csv, chunk 329, shape: (20000, 14)
# Processing sales.csv, chunk 330, shape: (20000, 14)
# Processing sales.csv, chunk 331, shape: (20000, 14)
# Processing sales.csv, chunk 332, shape: (20000, 14)
# Processing sales.csv, chunk 333, shape: (20000, 14)
# Processing sales.csv, chunk 334, shape: (20000, 14)
# Processing sales.csv, chunk 335, shape: (20000, 14)
# Processing sales.csv, chunk 336, shape: (20000, 14)
# Processing sales.csv, chunk 337, shape: (20000, 14)
# Processing sales.csv, chunk 338, shape: (20000, 14)
# Processing sales.csv, chunk 339, shape: (20000, 14)
# Processing sales.csv, chunk 340, shape: (20000, 14)
# Processing sales.csv, chunk 341, shape: (20000, 14)
# Processing sales.csv, chunk 342, shape: (20000, 14)
# Processing sales.csv, chunk 343, shape: (20000, 14)
# Processing sales.csv, chunk 344, shape: (20000, 14)
# Processing sales.csv, chunk 345, shape: (20000, 14)
# Processing sales.csv, chunk 346, shape: (20000, 14)
# Processing sales.csv, chunk 347, shape: (20000, 14)
# Processing sales.csv, chunk 348, shape: (20000, 14)
# Processing sales.csv, chunk 349, shape: (20000, 14)
# Processing sales.csv, chunk 350, shape: (20000, 14)
# Processing sales.csv, chunk 351, shape: (20000, 14)
# Processing sales.csv, chunk 352, shape: (20000, 14)
# Processing sales.csv, chunk 353, shape: (20000, 14)
# Processing sales.csv, chunk 354, shape: (20000, 14)
# Processing sales.csv, chunk 355, shape: (20000, 14)
# Processing sales.csv, chunk 356, shape: (20000, 14)
# Processing sales.csv, chunk 357, shape: (20000, 14)
# Processing sales.csv, chunk 358, shape: (20000, 14)
# Processing sales.csv, chunk 359, shape: (20000, 14)
# Processing sales.csv, chunk 360, shape: (20000, 14)
# Processing sales.csv, chunk 361, shape: (20000, 14)
# Processing sales.csv, chunk 362, shape: (20000, 14)
# Processing sales.csv, chunk 363, shape: (20000, 14)
# Processing sales.csv, chunk 364, shape: (20000, 14)
# Processing sales.csv, chunk 365, shape: (20000, 14)
# Processing sales.csv, chunk 366, shape: (20000, 14)
# Processing sales.csv, chunk 367, shape: (20000, 14)
# Processing sales.csv, chunk 368, shape: (20000, 14)
# Processing sales.csv, chunk 369, shape: (20000, 14)
# Processing sales.csv, chunk 370, shape: (20000, 14)
# Processing sales.csv, chunk 371, shape: (20000, 14)
# Processing sales.csv, chunk 372, shape: (20000, 14)
# Processing sales.csv, chunk 373, shape: (20000, 14)
# Processing sales.csv, chunk 374, shape: (20000, 14)
# Processing sales.csv, chunk 375, shape: (20000, 14)
# Processing sales.csv, chunk 376, shape: (20000, 14)
# Processing sales.csv, chunk 377, shape: (20000, 14)
# Processing sales.csv, chunk 378, shape: (20000, 14)
# Processing sales.csv, chunk 379, shape: (20000, 14)
# Processing sales.csv, chunk 380, shape: (20000, 14)
# Processing sales.csv, chunk 381, shape: (20000, 14)
# Processing sales.csv, chunk 382, shape: (20000, 14)
# Processing sales.csv, chunk 383, shape: (20000, 14)
# Processing sales.csv, chunk 384, shape: (20000, 14)
# Processing sales.csv, chunk 385, shape: (20000, 14)
# Processing sales.csv, chunk 386, shape: (20000, 14)
# Processing sales.csv, chunk 387, shape: (20000, 14)
# Processing sales.csv, chunk 388, shape: (20000, 14)
# Processing sales.csv, chunk 389, shape: (20000, 14)
# Processing sales.csv, chunk 390, shape: (20000, 14)
# Processing sales.csv, chunk 391, shape: (20000, 14)
# Processing sales.csv, chunk 392, shape: (20000, 14)
# Processing sales.csv, chunk 393, shape: (20000, 14)
# Processing sales.csv, chunk 394, shape: (20000, 14)
# Processing sales.csv, chunk 395, shape: (20000, 14)
# Processing sales.csv, chunk 396, shape: (20000, 14)
# Processing sales.csv, chunk 397, shape: (20000, 14)
# Processing sales.csv, chunk 398, shape: (20000, 14)
# Processing sales.csv, chunk 399, shape: (20000, 14)
# Processing sales.csv, chunk 400, shape: (20000, 14)
# Processing sales.csv, chunk 401, shape: (20000, 14)
# Processing sales.csv, chunk 402, shape: (20000, 14)
# Processing sales.csv, chunk 403, shape: (20000, 14)
# Processing sales.csv, chunk 404, shape: (20000, 14)
# Processing sales.csv, chunk 405, shape: (20000, 14)
# Processing sales.csv, chunk 406, shape: (20000, 14)
# Processing sales.csv, chunk 407, shape: (20000, 14)
# Processing sales.csv, chunk 408, shape: (20000, 14)
# Processing sales.csv, chunk 409, shape: (20000, 14)
# Processing sales.csv, chunk 410, shape: (20000, 14)
# Processing sales.csv, chunk 411, shape: (20000, 14)
# Processing sales.csv, chunk 412, shape: (20000, 14)
# Processing sales.csv, chunk 413, shape: (20000, 14)
# Processing sales.csv, chunk 414, shape: (20000, 14)
# Processing sales.csv, chunk 415, shape: (20000, 14)
# Processing sales.csv, chunk 416, shape: (20000, 14)
# Processing sales.csv, chunk 417, shape: (20000, 14)
# Processing sales.csv, chunk 418, shape: (20000, 14)
# Processing sales.csv, chunk 419, shape: (20000, 14)
# Processing sales.csv, chunk 420, shape: (20000, 14)
# Processing sales.csv, chunk 421, shape: (20000, 14)
# Processing sales.csv, chunk 422, shape: (20000, 14)
# Processing sales.csv, chunk 423, shape: (20000, 14)
# Processing sales.csv, chunk 424, shape: (20000, 14)
# Processing sales.csv, chunk 425, shape: (20000, 14)
# Processing sales.csv, chunk 426, shape: (20000, 14)
# Processing sales.csv, chunk 427, shape: (20000, 14)
# Processing sales.csv, chunk 428, shape: (20000, 14)
# Processing sales.csv, chunk 429, shape: (20000, 14)
# Processing sales.csv, chunk 430, shape: (20000, 14)
# Processing sales.csv, chunk 431, shape: (20000, 14)
# Processing sales.csv, chunk 432, shape: (20000, 14)
# Processing sales.csv, chunk 433, shape: (20000, 14)
# Processing sales.csv, chunk 434, shape: (20000, 14)
# Processing sales.csv, chunk 435, shape: (20000, 14)
# Processing sales.csv, chunk 436, shape: (20000, 14)
# Processing sales.csv, chunk 437, shape: (20000, 14)
# Processing sales.csv, chunk 438, shape: (20000, 14)
# Processing sales.csv, chunk 439, shape: (20000, 14)
# Processing sales.csv, chunk 440, shape: (20000, 14)
# Processing sales.csv, chunk 441, shape: (20000, 14)
# Processing sales.csv, chunk 442, shape: (20000, 14)
# Processing sales.csv, chunk 443, shape: (20000, 14)
# Processing sales.csv, chunk 444, shape: (20000, 14)
# Processing sales.csv, chunk 445, shape: (20000, 14)
# Processing sales.csv, chunk 446, shape: (20000, 14)
# Processing sales.csv, chunk 447, shape: (20000, 14)
# Processing sales.csv, chunk 448, shape: (20000, 14)
# Processing sales.csv, chunk 449, shape: (20000, 14)
# Processing sales.csv, chunk 450, shape: (20000, 14)
# Processing sales.csv, chunk 451, shape: (20000, 14)
# Processing sales.csv, chunk 452, shape: (20000, 14)
# Processing sales.csv, chunk 453, shape: (20000, 14)
# Processing sales.csv, chunk 454, shape: (20000, 14)
# Processing sales.csv, chunk 455, shape: (20000, 14)
# Processing sales.csv, chunk 456, shape: (20000, 14)
# Processing sales.csv, chunk 457, shape: (20000, 14)
# Processing sales.csv, chunk 458, shape: (20000, 14)
# Processing sales.csv, chunk 459, shape: (20000, 14)
# Processing sales.csv, chunk 460, shape: (20000, 14)
# Processing sales.csv, chunk 461, shape: (20000, 14)
# Processing sales.csv, chunk 462, shape: (20000, 14)
# Processing sales.csv, chunk 463, shape: (20000, 14)
# Processing sales.csv, chunk 464, shape: (20000, 14)
# Processing sales.csv, chunk 465, shape: (20000, 14)
# Processing sales.csv, chunk 466, shape: (20000, 14)
# Processing sales.csv, chunk 467, shape: (20000, 14)
# Processing sales.csv, chunk 468, shape: (20000, 14)
# Processing sales.csv, chunk 469, shape: (20000, 14)
# Processing sales.csv, chunk 470, shape: (20000, 14)
# Processing sales.csv, chunk 471, shape: (20000, 14)
# Processing sales.csv, chunk 472, shape: (20000, 14)
# Processing sales.csv, chunk 473, shape: (20000, 14)
# Processing sales.csv, chunk 474, shape: (20000, 14)
# Processing sales.csv, chunk 475, shape: (20000, 14)
# Processing sales.csv, chunk 476, shape: (20000, 14)
# Processing sales.csv, chunk 477, shape: (20000, 14)
# Processing sales.csv, chunk 478, shape: (20000, 14)
# Processing sales.csv, chunk 479, shape: (20000, 14)
# Processing sales.csv, chunk 480, shape: (20000, 14)
# Processing sales.csv, chunk 481, shape: (20000, 14)
# Processing sales.csv, chunk 482, shape: (20000, 14)
# Processing sales.csv, chunk 483, shape: (20000, 14)
# Processing sales.csv, chunk 484, shape: (20000, 14)
# Processing sales.csv, chunk 485, shape: (20000, 14)
# Processing sales.csv, chunk 486, shape: (20000, 14)
# Processing sales.csv, chunk 487, shape: (20000, 14)
# Processing sales.csv, chunk 488, shape: (20000, 14)
# Processing sales.csv, chunk 489, shape: (20000, 14)
# Processing sales.csv, chunk 490, shape: (20000, 14)
# Processing sales.csv, chunk 491, shape: (20000, 14)
# Processing sales.csv, chunk 492, shape: (20000, 14)
# Processing sales.csv, chunk 493, shape: (20000, 14)
# Processing sales.csv, chunk 494, shape: (20000, 14)
# Processing sales.csv, chunk 495, shape: (20000, 14)
# Processing sales.csv, chunk 496, shape: (20000, 14)
# Processing sales.csv, chunk 497, shape: (20000, 14)
# Processing sales.csv, chunk 498, shape: (20000, 14)
# Processing sales.csv, chunk 499, shape: (20000, 14)
# Processing sales.csv, chunk 500, shape: (20000, 14)
# Processing sales.csv, chunk 501, shape: (20000, 14)
# Processing sales.csv, chunk 502, shape: (20000, 14)
# Processing sales.csv, chunk 503, shape: (20000, 14)
# Processing sales.csv, chunk 504, shape: (20000, 14)
# Processing sales.csv, chunk 505, shape: (20000, 14)
# Processing sales.csv, chunk 506, shape: (20000, 14)
# Processing sales.csv, chunk 507, shape: (20000, 14)
# Processing sales.csv, chunk 508, shape: (20000, 14)
# Processing sales.csv, chunk 509, shape: (20000, 14)
# Processing sales.csv, chunk 510, shape: (20000, 14)
# Processing sales.csv, chunk 511, shape: (20000, 14)
# Processing sales.csv, chunk 512, shape: (20000, 14)
# Processing sales.csv, chunk 513, shape: (20000, 14)
# Processing sales.csv, chunk 514, shape: (20000, 14)
# Processing sales.csv, chunk 515, shape: (20000, 14)
# Processing sales.csv, chunk 516, shape: (20000, 14)
# Processing sales.csv, chunk 517, shape: (20000, 14)
# Processing sales.csv, chunk 518, shape: (20000, 14)
# Processing sales.csv, chunk 519, shape: (20000, 14)
# Processing sales.csv, chunk 520, shape: (20000, 14)
# Processing sales.csv, chunk 521, shape: (20000, 14)
# Processing sales.csv, chunk 522, shape: (20000, 14)
# Processing sales.csv, chunk 523, shape: (20000, 14)
# Processing sales.csv, chunk 524, shape: (20000, 14)
# Processing sales.csv, chunk 525, shape: (20000, 14)
# Processing sales.csv, chunk 526, shape: (20000, 14)
# Processing sales.csv, chunk 527, shape: (20000, 14)
# Processing sales.csv, chunk 528, shape: (20000, 14)
# Processing sales.csv, chunk 529, shape: (20000, 14)
# Processing sales.csv, chunk 530, shape: (20000, 14)
# Processing sales.csv, chunk 531, shape: (20000, 14)
# Processing sales.csv, chunk 532, shape: (20000, 14)
# Processing sales.csv, chunk 533, shape: (20000, 14)
# Processing sales.csv, chunk 534, shape: (20000, 14)
# Processing sales.csv, chunk 535, shape: (20000, 14)
# Processing sales.csv, chunk 536, shape: (20000, 14)
# Processing sales.csv, chunk 537, shape: (20000, 14)
# Processing sales.csv, chunk 538, shape: (20000, 14)
# Processing sales.csv, chunk 539, shape: (20000, 14)
# Processing sales.csv, chunk 540, shape: (20000, 14)
# Processing sales.csv, chunk 541, shape: (20000, 14)
# Processing sales.csv, chunk 542, shape: (20000, 14)
# Processing sales.csv, chunk 543, shape: (20000, 14)
# Processing sales.csv, chunk 544, shape: (20000, 14)
# Processing sales.csv, chunk 545, shape: (20000, 14)
# Processing sales.csv, chunk 546, shape: (20000, 14)
# Processing sales.csv, chunk 547, shape: (20000, 14)
# Processing sales.csv, chunk 548, shape: (20000, 14)
# Processing sales.csv, chunk 549, shape: (20000, 14)
# Processing sales.csv, chunk 550, shape: (20000, 14)
# Processing sales.csv, chunk 551, shape: (20000, 14)
# Processing sales.csv, chunk 552, shape: (20000, 14)
# Processing sales.csv, chunk 553, shape: (20000, 14)
# Processing sales.csv, chunk 554, shape: (20000, 14)
# Processing sales.csv, chunk 555, shape: (20000, 14)
# Processing sales.csv, chunk 556, shape: (20000, 14)
# Processing sales.csv, chunk 557, shape: (20000, 14)
# Processing sales.csv, chunk 558, shape: (20000, 14)
# Processing sales.csv, chunk 559, shape: (20000, 14)
# Processing sales.csv, chunk 560, shape: (20000, 14)
# Processing sales.csv, chunk 561, shape: (20000, 14)
# Processing sales.csv, chunk 562, shape: (20000, 14)
# Processing sales.csv, chunk 563, shape: (20000, 14)
# Processing sales.csv, chunk 564, shape: (20000, 14)
# Processing sales.csv, chunk 565, shape: (20000, 14)
# Processing sales.csv, chunk 566, shape: (20000, 14)
# Processing sales.csv, chunk 567, shape: (20000, 14)
# Processing sales.csv, chunk 568, shape: (20000, 14)
# Processing sales.csv, chunk 569, shape: (20000, 14)
# Processing sales.csv, chunk 570, shape: (20000, 14)
# Processing sales.csv, chunk 571, shape: (20000, 14)
# Processing sales.csv, chunk 572, shape: (20000, 14)
# Processing sales.csv, chunk 573, shape: (20000, 14)
# Processing sales.csv, chunk 574, shape: (20000, 14)
# Processing sales.csv, chunk 575, shape: (20000, 14)
# Processing sales.csv, chunk 576, shape: (20000, 14)
# Processing sales.csv, chunk 577, shape: (20000, 14)
# Processing sales.csv, chunk 578, shape: (20000, 14)
# Processing sales.csv, chunk 579, shape: (20000, 14)
# Processing sales.csv, chunk 580, shape: (20000, 14)
# Processing sales.csv, chunk 581, shape: (20000, 14)
# Processing sales.csv, chunk 582, shape: (20000, 14)
# Processing sales.csv, chunk 583, shape: (20000, 14)
# Processing sales.csv, chunk 584, shape: (20000, 14)
# Processing sales.csv, chunk 585, shape: (20000, 14)
# Processing sales.csv, chunk 586, shape: (20000, 14)
# Processing sales.csv, chunk 587, shape: (20000, 14)
# Processing sales.csv, chunk 588, shape: (20000, 14)
# Processing sales.csv, chunk 589, shape: (20000, 14)
# Processing sales.csv, chunk 590, shape: (20000, 14)
# Processing sales.csv, chunk 591, shape: (20000, 14)
# Processing sales.csv, chunk 592, shape: (20000, 14)
# Processing sales.csv, chunk 593, shape: (20000, 14)
# Processing sales.csv, chunk 594, shape: (20000, 14)
# Processing sales.csv, chunk 595, shape: (20000, 14)
# Processing sales.csv, chunk 596, shape: (20000, 14)
# Processing sales.csv, chunk 597, shape: (20000, 14)
# Processing sales.csv, chunk 598, shape: (20000, 14)
# Processing sales.csv, chunk 599, shape: (20000, 14)
# Processing sales.csv, chunk 600, shape: (20000, 14)
# Processing sales.csv, chunk 601, shape: (20000, 14)
# Processing sales.csv, chunk 602, shape: (20000, 14)
# Processing sales.csv, chunk 603, shape: (20000, 14)
# Processing sales.csv, chunk 604, shape: (20000, 14)
# Processing sales.csv, chunk 605, shape: (20000, 14)
# Processing sales.csv, chunk 606, shape: (20000, 14)
# Processing sales.csv, chunk 607, shape: (20000, 14)
# Processing sales.csv, chunk 608, shape: (20000, 14)
# Processing sales.csv, chunk 609, shape: (20000, 14)
# Processing sales.csv, chunk 610, shape: (20000, 14)
# Processing sales.csv, chunk 611, shape: (20000, 14)
# Processing sales.csv, chunk 612, shape: (20000, 14)
# Processing sales.csv, chunk 613, shape: (20000, 14)
# Processing sales.csv, chunk 614, shape: (20000, 14)
# Processing sales.csv, chunk 615, shape: (20000, 14)
# Processing sales.csv, chunk 616, shape: (20000, 14)
# Processing sales.csv, chunk 617, shape: (20000, 14)
# Processing sales.csv, chunk 618, shape: (20000, 14)
# Processing sales.csv, chunk 619, shape: (20000, 14)
# Processing sales.csv, chunk 620, shape: (20000, 14)
# Processing sales.csv, chunk 621, shape: (20000, 14)
# Processing sales.csv, chunk 622, shape: (20000, 14)
# Processing sales.csv, chunk 623, shape: (20000, 14)
# Processing sales.csv, chunk 624, shape: (20000, 14)
# Processing sales.csv, chunk 625, shape: (20000, 14)
# Processing sales.csv, chunk 626, shape: (20000, 14)
# Processing sales.csv, chunk 627, shape: (20000, 14)
# Processing sales.csv, chunk 628, shape: (20000, 14)
# Processing sales.csv, chunk 629, shape: (20000, 14)
# Processing sales.csv, chunk 630, shape: (20000, 14)
# Processing sales.csv, chunk 631, shape: (20000, 14)
# Processing sales.csv, chunk 632, shape: (20000, 14)
# Processing sales.csv, chunk 633, shape: (20000, 14)
# Processing sales.csv, chunk 634, shape: (20000, 14)
# Processing sales.csv, chunk 635, shape: (20000, 14)
# Processing sales.csv, chunk 636, shape: (20000, 14)
# Processing sales.csv, chunk 637, shape: (20000, 14)
# Processing sales.csv, chunk 638, shape: (20000, 14)
# Processing sales.csv, chunk 639, shape: (20000, 14)
# Processing sales.csv, chunk 640, shape: (20000, 14)
# 2025-06-27 10:57:16,254 - INFO - Completed processing sales.csv - Total rows: 12825363
# 2025-06-27 10:57:16,256 - INFO - Starting to process file: vendor_invoice.csv
# Processing sales.csv, chunk 641, shape: (5363, 14)
# Completed processing sales.csv - Total rows: 12825363
# 2025-06-27 10:57:16,468 - INFO - Completed processing vendor_invoice.csv - Total rows: 5543
# 2025-06-27 10:57:16,469 - INFO - -------------Ingestion Complete------------
# 2025-06-27 10:57:16,471 - INFO - Total Time Taken: 10.81 minutes
# Processing vendor_invoice.csv, chunk 0, shape: (5543, 10)
# Completed processing vendor_invoice.csv - Total rows: 5543
# Total Time Taken: 10.81 minutes
